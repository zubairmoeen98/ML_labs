# %% [markdown]
# # Lab 2.2: Introduction to Pandas
#
# **Name:** Zubair Moeen
# **Reg Number:** 22jzele0463
# **Lab:** Machine Learning Lab
# **Lab Supervisor:** Engr.Irshad Ullah
# **University:** UET Peshawar - Campus Nowshera
#
# ## Lab Overview
# This notebook introduces Pandas for data handling and data analysis. The code demonstrates Series, DataFrames, CSV loading, indexing, grouping, filtering, and basic data inspection.
#
# ## Learning Objectives
# - Import Pandas and create DataFrames from dictionaries and arrays.
# - Read tabular data from CSV files using Pandas.
# - Inspect data using head, tail, info, describe, and shape.
# - Practice indexing, filtering, grouping, and basic DataFrame operations used in ML data preparation.

# %% [markdown]
# ## Section 1: Pandas Setup and DataFrame Creation
# This section introduces Pandas and creates tabular data manually. This is the same structure used later when datasets are loaded for machine learning.

# %% [markdown]
# ### Introduction To Pandas Module
# Here, we are learning data analysis. Pandas is a software library written for the Python programming language that helps with data manipulation and analysis. It offers various data structures which help in the manipulation of data. <br>
# One of the data structures used is DataFrame.<br>
# DataFrame is used as a way to store data in a rectangular grid.<br>
# Similar to how data is stored in Microsoft Excel.
# ### Installation
# We can easily install this library using the terminal. Follow the steps given below to install Pandas:<br>
# Step 1: Go to the Windows PowerShell.<br>
# Step 2: We can install pandas with the help of pip easily. Head over to the directory where you want to install the pandas and fire the below command:<br>
# __pip install pandas__<br>
# This is very simple to install.

# %%
# !pip install pandas

# %% [markdown]
# ### import pandas
# Once Pandas is installed, import it in your applications by adding the import keyword:<br>
# __import pandas as pd__<br>
# Now Pandas is imported and ready to use.

# %%
import pandas

# %%
students = {
    'Name': ["Daniyal Basharat", " M Abdullah", "Muhammad Abid", "Shumail Khan","Qasim Ali"],
    'Marks': [80, 72, 77, 65, 15],
    'Class':["1st Year", "2nd Year", "1st Year", "3rd Year", "2nd Year"],
    'Age': [20, 21, 19, 22, 21]
}

# %%
df = pandas.DataFrame(students)

# %%
df
# Out:
#                Name  Marks     Class  Age
# 0  Daniyal Basharat     80  1st Year   20
# 1        M Abdullah     72  2nd Year   21
# 2     Muhammad Abid     77  1st Year   19
# 3      Shumail Khan     65  3rd Year   22
# 4         Qasim Ali     15  2nd Year   21

# %% [markdown]
# ### Pandas as pd
# Pandas is usually imported under the pd alias.
# #### alias:
# In Python alias are an alternate name for referring to the same thing.<br>
# Create an alias with the as keyword while importing:<br>
# __import pandas as pd__<br>
# Now the Pandas package can be referred to as pd instead of pandas.

# %%
import pandas as pd

# %%
df = pd.DataFrame(students)

# %%
df
# Out:
#                Name  Marks     Class  Age
# 0  Daniyal Basharat     80  1st Year   20
# 1        M Abdullah     72  2nd Year   21
# 2     Muhammad Abid     77  1st Year   19
# 3      Shumail Khan     65  3rd Year   22
# 4         Qasim Ali     15  2nd Year   21

# %% [markdown]
# ### Checking Pandas Version
# The version string is stored under __version__ attribute.

# %%
pd.__version__
# Out:
# '3.0.3'

# %% [markdown]
# ## Saving to CSV and other extensions like excel

# %%
df.to_csv('pythonMonday.csv')

# %% [markdown]
# ## Remove Index and saving the csv file

# %%
df.to_csv('pythonMondayRemoveIndex.csv', index=False)

# %% [markdown]
# ## Show some rows from the Start

# %%
df.head()
# Out:
#                Name  Marks     Class  Age
# 0  Daniyal Basharat     80  1st Year   20
# 1        M Abdullah     72  2nd Year   21
# 2     Muhammad Abid     77  1st Year   19
# 3      Shumail Khan     65  3rd Year   22
# 4         Qasim Ali     15  2nd Year   21

# %% [markdown]
# ## Specify No of rows to show

# %%
df.head(3)
# Out:
#                Name  Marks     Class  Age
# 0  Daniyal Basharat     80  1st Year   20
# 1        M Abdullah     72  2nd Year   21
# 2     Muhammad Abid     77  1st Year   19

# %%
df.tail(3)
# Out:
#             Name  Marks     Class  Age
# 2  Muhammad Abid     77  1st Year   19
# 3   Shumail Khan     65  3rd Year   22
# 4      Qasim Ali     15  2nd Year   21

# %%
df.tail()
# Out:
#                Name  Marks     Class  Age
# 0  Daniyal Basharat     80  1st Year   20
# 1        M Abdullah     72  2nd Year   21
# 2     Muhammad Abid     77  1st Year   19
# 3      Shumail Khan     65  3rd Year   22
# 4         Qasim Ali     15  2nd Year   21

# %%
df.describe()
# Out:
#            Marks        Age
# count   5.000000   5.000000
# mean   61.800000  20.600000
# std    26.771253   1.140175
# min    15.000000  19.000000
# 25%    65.000000  20.000000
# 50%    72.000000  21.000000
# 75%    77.000000  21.000000
# max    80.000000  22.000000

# %% [markdown]
# # Reading csv or other files

# %%
classData= pd.read_csv("pythonMondayRemoveIndex.csv")
classData
# Out:
#                Name  Marks     Class  Age
# 0  Daniyal Basharat     80  1st Year   20
# 1        M Abdullah     72  2nd Year   21
# 2     Muhammad Abid     77  1st Year   19
# 3      Shumail Khan     65  3rd Year   22
# 4         Qasim Ali     15  2nd Year   21

# %%
classData= pd.read_csv("pythonMonday.csv")
classData
# Out:
#    Unnamed: 0              Name  Marks     Class  Age
# 0           0  Daniyal Basharat     80  1st Year   20
# 1           1        M Abdullah     72  2nd Year   21
# 2           2     Muhammad Abid     77  1st Year   19
# 3           3      Shumail Khan     65  3rd Year   22
# 4           4         Qasim Ali     15  2nd Year   21

# %%
classData.drop('Name', axis=1)
# Out:
#    Unnamed: 0  Marks     Class  Age
# 0           0     80  1st Year   20
# 1           1     72  2nd Year   21
# 2           2     77  1st Year   19
# 3           3     65  3rd Year   22
# 4           4     15  2nd Year   21

# %%
classData
# Out:
#    Unnamed: 0              Name  Marks     Class  Age
# 0           0  Daniyal Basharat     80  1st Year   20
# 1           1        M Abdullah     72  2nd Year   21
# 2           2     Muhammad Abid     77  1st Year   19
# 3           3      Shumail Khan     65  3rd Year   22
# 4           4         Qasim Ali     15  2nd Year   21

# %%
classData.drop(0, axis=0)
# Out:
#    Unnamed: 0           Name  Marks     Class  Age
# 1           1     M Abdullah     72  2nd Year   21
# 2           2  Muhammad Abid     77  1st Year   19
# 3           3   Shumail Khan     65  3rd Year   22
# 4           4      Qasim Ali     15  2nd Year   21

# %%
classData
# Out:
#    Unnamed: 0              Name  Marks     Class  Age
# 0           0  Daniyal Basharat     80  1st Year   20
# 1           1        M Abdullah     72  2nd Year   21
# 2           2     Muhammad Abid     77  1st Year   19
# 3           3      Shumail Khan     65  3rd Year   22
# 4           4         Qasim Ali     15  2nd Year   21

# %% [markdown]
# # Check the spelling

# %%
classData['Class']
# Out:
# 0    1st Year
# 1    2nd Year
# 2    1st Year
# 3    3rd Year
# 4    2nd Year
# Name: Class, dtype: str

# %% [markdown]
# # Check the trail space

# %%
classData.columns = classData.columns.str.strip().str.lower()

# %%
classData['class']
# Out:
# 0    1st Year
# 1    2nd Year
# 2    1st Year
# 3    3rd Year
# 4    2nd Year
# Name: class, dtype: str

# %% [markdown]
# # Corrected Spelling

# %%
classData['name']
# Out:
# 0    Daniyal Basharat
# 1          M Abdullah
# 2       Muhammad Abid
# 3        Shumail Khan
# 4           Qasim Ali
# Name: name, dtype: str

# %% [markdown]
# # Check the head space

# %%
classData['name']
# Out:
# 0    Daniyal Basharat
# 1          M Abdullah
# 2       Muhammad Abid
# 3        Shumail Khan
# 4           Qasim Ali
# Name: name, dtype: str

# %%
type(classData['name'])
# Out:
# pandas.Series

# %%
classData['age']
# Out:
# 0    20
# 1    21
# 2    19
# 3    22
# 4    21
# Name: age, dtype: int64

# %% [markdown]
# classData['gpa'][0]

# %%
classData['age'][0]
# Out:
# np.int64(20)

# %%
classData['age'][0]=90
# Out:
# C:\Users\engin\AppData\Local\Temp\ipykernel_23084\3711599208.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   classData['age'][0]=90

# %%
classData
# Out:
#    unnamed: 0              name  marks     class  age
# 0           0  Daniyal Basharat     80  1st Year   20
# 1           1        M Abdullah     72  2nd Year   21
# 2           2     Muhammad Abid     77  1st Year   19
# 3           3      Shumail Khan     65  3rd Year   22
# 4           4         Qasim Ali     15  2nd Year   21

# %%
classData['age'][4]
# Out:
# np.int64(21)

# %%
classData['age'][4]=5
# Out:
# C:\Users\engin\AppData\Local\Temp\ipykernel_23084\2197085196.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   classData['age'][4]=5

# %%
classData["name"][4]
# Out:
# 'Qasim Ali'

# %% [markdown]
# # Rename the column name

# %% [markdown]
# ## Section 2: Reading and Inspecting Data
# The following cells load data and inspect its rows, columns, summary, and structure. This step is necessary before cleaning or modeling any dataset.

# %%
classData.rename(columns={'age': 'AGE'})
# Out:
#    unnamed: 0              name  marks     class  AGE
# 0           0  Daniyal Basharat     80  1st Year   20
# 1           1        M Abdullah     72  2nd Year   21
# 2           2     Muhammad Abid     77  1st Year   19
# 3           3      Shumail Khan     65  3rd Year   22
# 4           4         Qasim Ali     15  2nd Year   21

# %% [markdown]
# ## Create Labels
# With the index argument, you can name your own labels.

# %%
classData.index = ["First","Second", "Third", "Fourth", "Fifth"]
classData
# Out:
#         unnamed: 0              name  marks     class  age
# First            0  Daniyal Basharat     80  1st Year   20
# Second           1        M Abdullah     72  2nd Year   21
# Third            2     Muhammad Abid     77  1st Year   19
# Fourth           3      Shumail Khan     65  3rd Year   22
# Fifth            4         Qasim Ali     15  2nd Year   21

# %% [markdown]
# # Asignment

# %%
classdata = classData.drop('unnamed: 0', axis=1)
classData
# Out:
#         unnamed: 0              name  marks     class  age
# First            0  Daniyal Basharat     80  1st Year   20
# Second           1        M Abdullah     72  2nd Year   21
# Third            2     Muhammad Abid     77  1st Year   19
# Fourth           3      Shumail Khan     65  3rd Year   22
# Fifth            4         Qasim Ali     15  2nd Year   21

# %% [markdown]
# # Inplace

# %%
classData.drop('unnamed: 0', axis=1, inplace = True)
classData
# Out:
#                     name  marks     class  age
# First   Daniyal Basharat     80  1st Year   20
# Second        M Abdullah     72  2nd Year   21
# Third      Muhammad Abid     77  1st Year   19
# Fourth      Shumail Khan     65  3rd Year   22
# Fifth          Qasim Ali     15  2nd Year   21

# %% [markdown]
# # Accessing the value in Dataframe

# %%
classData["name"]
# Out:
# First     Daniyal Basharat
# Second          M Abdullah
# Third        Muhammad Abid
# Fourth        Shumail Khan
# Fifth            Qasim Ali
# Name: name, dtype: str

# %%
classData["name"]["Fifth"]
# Out:
# 'Qasim Ali'

# %% [markdown]
# ## Pandas
# Pandas is an open source data analysis library written in Python.<br>
# It uses the power and speed of numpy to make data analysis and preprocessing easy for data scientists.<br>
# __Pandas__ is used to analyze data.<br>
# Python data analysis using pandas is a great start to Exploratory Data Analysis (EDA) for a data scientist.

# %% [markdown]
# ## Pandas Data Structure
# Panda has two types of Data Structure:<br>
#     a) Series<br>
#     b) Dataframe
# ### Series
# It is a one dimentional array with indexes. It stores a single column or row of data in a Dataframe.<br>
# It is a one dimensional array capable of holding any type of data.
# ### Dataframe
# It is a tabular spreadsheet like structure representing rows each of which contains one or more columns.<br>
# It is a multi dimensional array capable of holding any type of data.<br>
# __Series__ is like a column, a __DataFrame__ is the whole table.

# %%
classData['age']
# Out:
# First     20
# Second    21
# Third     19
# Fourth    22
# Fifth     21
# Name: age, dtype: int64

# %%
type(classData['age'])
# Out:
# pandas.Series

# %%
classData
# Out:
#                     name  marks     class  age
# First   Daniyal Basharat     80  1st Year   20
# Second        M Abdullah     72  2nd Year   21
# Third      Muhammad Abid     77  1st Year   19
# Fourth      Shumail Khan     65  3rd Year   22
# Fifth          Qasim Ali     15  2nd Year   21

# %%
type(classData)
# Out:
# pandas.DataFrame

# %%
import numpy as np

# %%
series1= pd.Series(np.random.rand())

# %%
series1
# Out:
# 0    0.327954
# dtype: float64

# %%
series1= pd.Series(np.random.rand(30))

# %%
series1
# Out:
# 0     0.207264
# 1     0.886030
# 2     0.677933
# 3     0.925075
# 4     0.208772
# 5     0.567059
# 6     0.393802
# 7     0.979793
# 8     0.254350
# 9     0.349803
# 10    0.521871
# 11    0.186780
# 12    0.846777
# 13    0.409501
# 14    0.768378
# 15    0.508890
# 16    0.227237
# 17    0.276464
# 18    0.777496
# 19    0.973054
# 20    0.829727
# 21    0.498694
# 22    0.856162
# 23    0.851743
# 24    0.187558
# 25    0.685566
# 26    0.862057
# 27    0.884114
# 28    0.812214
# 29    0.194582
# dtype: float64

# %%
type(series1)
# Out:
# pandas.Series

# %%
np.random.rand(3,4)
# Out:
# array([[0.7854323 , 0.90711308, 0.49810243, 0.93252121],
#        [0.86993701, 0.02689601, 0.15401106, 0.78832567],
#        [0.55494707, 0.18184171, 0.19798219, 0.90246619]])

# %%
newDf = pd.DataFrame(np.random.rand(330,5))
# newDf = pd.DataFrame(np.random.rand(330,5), index=np.arange(330))

# %%
type(newDf)
# Out:
# pandas.DataFrame

# %%
newDf.head(2)
# Out:
#           0         1         2         3         4
# 0  0.991731  0.572531  0.226080  0.785044  0.312688
# 1  0.672409  0.362699  0.977462  0.684656  0.051541

# %%
newDf.tail(2)
# Out:
#             0         1         2         3         4
# 328  0.366406  0.289725  0.441839  0.138079  0.876813
# 329  0.062353  0.610841  0.617779  0.770804  0.667743

# %%
newDf.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 330 entries, 0 to 329
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       330 non-null    float64
#  1   1       330 non-null    float64
#  2   2       330 non-null    float64
#  3   3       330 non-null    float64
#  4   4       330 non-null    float64
# dtypes: float64(5)
# memory usage: 13.0 KB

# %%
newDf.describe()
# Out:
#                 0           1           2           3           4
# count  330.000000  330.000000  330.000000  330.000000  330.000000
# mean     0.520924    0.490805    0.516608    0.511740    0.480037
# std      0.282574    0.273847    0.287705    0.296940    0.291652
# min      0.003324    0.002827    0.001994    0.001489    0.003425
# 25%      0.291378    0.257856    0.288632    0.268635    0.241281
# 50%      0.519534    0.501465    0.511080    0.535888    0.486812
# 75%      0.772733    0.713856    0.775031    0.770147    0.707220
# max      0.995381    0.996958    0.996648    0.996858    0.995708

# %%
newDf.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %% [markdown]
# # Change the value inside the dataframe

# %%
newDf[0][0]= 10000.0
# Out:
# C:\Users\engin\AppData\Local\Temp\ipykernel_23084\1615845312.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   newDf[0][0]= 10000.0

# %%
newDf
# Out:
#             0         1         2         3         4
# 0    0.991731  0.572531  0.226080  0.785044  0.312688
# 1    0.672409  0.362699  0.977462  0.684656  0.051541
# 2    0.781430  0.776446  0.975886  0.006406  0.604181
# 3    0.365634  0.717888  0.666372  0.766964  0.724479
# 4    0.559252  0.744348  0.626295  0.547583  0.383909
# ..        ...       ...       ...       ...       ...
# 325  0.751106  0.664774  0.394318  0.359376  0.102661
# 326  0.726212  0.059307  0.445704  0.804760  0.095875
# 327  0.722779  0.566993  0.560390  0.779230  0.137043
# 328  0.366406  0.289725  0.441839  0.138079  0.876813
# 329  0.062353  0.610841  0.617779  0.770804  0.667743
#
# [330 rows x 5 columns]

# %%
newDf.head()
# Out:
#           0         1         2         3         4
# 0  0.991731  0.572531  0.226080  0.785044  0.312688
# 1  0.672409  0.362699  0.977462  0.684656  0.051541
# 2  0.781430  0.776446  0.975886  0.006406  0.604181
# 3  0.365634  0.717888  0.666372  0.766964  0.724479
# 4  0.559252  0.744348  0.626295  0.547583  0.383909

# %% [markdown]
# # Transpose

# %%
newDf.T
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.991731  0.672409  0.781430  0.365634  0.559252  0.339411  0.570001
# 1  0.572531  0.362699  0.776446  0.717888  0.744348  0.639770  0.674737
# 2  0.226080  0.977462  0.975886  0.666372  0.626295  0.824962  0.775190
# 3  0.785044  0.684656  0.006406  0.766964  0.547583  0.265944  0.272686
# 4  0.312688  0.051541  0.604181  0.724479  0.383909  0.750294  0.529988
#
#         7         8         9    ...       320       321       322       323  \
# 0  0.944128  0.972929  0.440632  ...  0.839565  0.667264  0.102684  0.603408
# 1  0.555956  0.312573  0.060348  ...  0.821073  0.257591  0.056174  0.274813
# 2  0.486691  0.128505  0.536030  ...  0.925724  0.507778  0.900472  0.347152
# 3  0.895129  0.433506  0.612827  ...  0.278285  0.021876  0.227891  0.931690
# 4  0.027352  0.764012  0.058605  ...  0.700861  0.478463  0.635164  0.705882
#
#         324       325       326       327       328       329
# 0  0.794621  0.751106  0.726212  0.722779  0.366406  0.062353
# 1  0.556044  0.664774  0.059307  0.566993  0.289725  0.610841
# 2  0.359814  0.394318  0.445704  0.560390  0.441839  0.617779
# 3  0.106332  0.359376  0.804760  0.779230  0.138079  0.770804
# 4  0.239565  0.102661  0.095875  0.137043  0.876813  0.667743
#
# [5 rows x 330 columns]

# %% [markdown]
# # Sorting

# %%
newDf.sort_index(axis=0)
# Out:
#             0         1         2         3         4
# 0    0.991731  0.572531  0.226080  0.785044  0.312688
# 1    0.672409  0.362699  0.977462  0.684656  0.051541
# 2    0.781430  0.776446  0.975886  0.006406  0.604181
# 3    0.365634  0.717888  0.666372  0.766964  0.724479
# 4    0.559252  0.744348  0.626295  0.547583  0.383909
# ..        ...       ...       ...       ...       ...
# 325  0.751106  0.664774  0.394318  0.359376  0.102661
# 326  0.726212  0.059307  0.445704  0.804760  0.095875
# 327  0.722779  0.566993  0.560390  0.779230  0.137043
# 328  0.366406  0.289725  0.441839  0.138079  0.876813
# 329  0.062353  0.610841  0.617779  0.770804  0.667743
#
# [330 rows x 5 columns]

# %%
newDf.sort_index(axis=0, ascending=False)
# Out:
#             0         1         2         3         4
# 329  0.062353  0.610841  0.617779  0.770804  0.667743
# 328  0.366406  0.289725  0.441839  0.138079  0.876813
# 327  0.722779  0.566993  0.560390  0.779230  0.137043
# 326  0.726212  0.059307  0.445704  0.804760  0.095875
# 325  0.751106  0.664774  0.394318  0.359376  0.102661
# ..        ...       ...       ...       ...       ...
# 4    0.559252  0.744348  0.626295  0.547583  0.383909
# 3    0.365634  0.717888  0.666372  0.766964  0.724479
# 2    0.781430  0.776446  0.975886  0.006406  0.604181
# 1    0.672409  0.362699  0.977462  0.684656  0.051541
# 0    0.991731  0.572531  0.226080  0.785044  0.312688
#
# [330 rows x 5 columns]

# %%
newDf.sort_index(axis=1)
# Out:
#             0         1         2         3         4
# 0    0.991731  0.572531  0.226080  0.785044  0.312688
# 1    0.672409  0.362699  0.977462  0.684656  0.051541
# 2    0.781430  0.776446  0.975886  0.006406  0.604181
# 3    0.365634  0.717888  0.666372  0.766964  0.724479
# 4    0.559252  0.744348  0.626295  0.547583  0.383909
# ..        ...       ...       ...       ...       ...
# 325  0.751106  0.664774  0.394318  0.359376  0.102661
# 326  0.726212  0.059307  0.445704  0.804760  0.095875
# 327  0.722779  0.566993  0.560390  0.779230  0.137043
# 328  0.366406  0.289725  0.441839  0.138079  0.876813
# 329  0.062353  0.610841  0.617779  0.770804  0.667743
#
# [330 rows x 5 columns]

# %%
newDf.sort_index(axis=1, ascending=False)
# Out:
#             4         3         2         1         0
# 0    0.312688  0.785044  0.226080  0.572531  0.991731
# 1    0.051541  0.684656  0.977462  0.362699  0.672409
# 2    0.604181  0.006406  0.975886  0.776446  0.781430
# 3    0.724479  0.766964  0.666372  0.717888  0.365634
# 4    0.383909  0.547583  0.626295  0.744348  0.559252
# ..        ...       ...       ...       ...       ...
# 325  0.102661  0.359376  0.394318  0.664774  0.751106
# 326  0.095875  0.804760  0.445704  0.059307  0.726212
# 327  0.137043  0.779230  0.560390  0.566993  0.722779
# 328  0.876813  0.138079  0.441839  0.289725  0.366406
# 329  0.667743  0.770804  0.617779  0.610841  0.062353
#
# [330 rows x 5 columns]

# %%
newDf.head()
# Out:
#           0         1         2         3         4
# 0  0.991731  0.572531  0.226080  0.785044  0.312688
# 1  0.672409  0.362699  0.977462  0.684656  0.051541
# 2  0.781430  0.776446  0.975886  0.006406  0.604181
# 3  0.365634  0.717888  0.666372  0.766964  0.724479
# 4  0.559252  0.744348  0.626295  0.547583  0.383909

# %%
newDf[0][1]
# Out:
# np.float64(0.6724089936169542)

# %%
type(newDf[0])
# Out:
# pandas.Series

# %%
newDf
# Out:
#             0         1         2         3         4
# 0    0.991731  0.572531  0.226080  0.785044  0.312688
# 1    0.672409  0.362699  0.977462  0.684656  0.051541
# 2    0.781430  0.776446  0.975886  0.006406  0.604181
# 3    0.365634  0.717888  0.666372  0.766964  0.724479
# 4    0.559252  0.744348  0.626295  0.547583  0.383909
# ..        ...       ...       ...       ...       ...
# 325  0.751106  0.664774  0.394318  0.359376  0.102661
# 326  0.726212  0.059307  0.445704  0.804760  0.095875
# 327  0.722779  0.566993  0.560390  0.779230  0.137043
# 328  0.366406  0.289725  0.441839  0.138079  0.876813
# 329  0.062353  0.610841  0.617779  0.770804  0.667743
#
# [330 rows x 5 columns]

# %% [markdown]
# ## view

# %%
newDfView=newDf

# %%
newDfView
# Out:
#             0         1         2         3         4
# 0    0.991731  0.572531  0.226080  0.785044  0.312688
# 1    0.672409  0.362699  0.977462  0.684656  0.051541
# 2    0.781430  0.776446  0.975886  0.006406  0.604181
# 3    0.365634  0.717888  0.666372  0.766964  0.724479
# 4    0.559252  0.744348  0.626295  0.547583  0.383909
# ..        ...       ...       ...       ...       ...
# 325  0.751106  0.664774  0.394318  0.359376  0.102661
# 326  0.726212  0.059307  0.445704  0.804760  0.095875
# 327  0.722779  0.566993  0.560390  0.779230  0.137043
# 328  0.366406  0.289725  0.441839  0.138079  0.876813
# 329  0.062353  0.610841  0.617779  0.770804  0.667743
#
# [330 rows x 5 columns]

# %%
newDfView[0][0]=765
# Out:
# C:\Users\engin\AppData\Local\Temp\ipykernel_23084\4063526219.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   newDfView[0][0]=765

# %%
newDf.head()
# Out:
#           0         1         2         3         4
# 0  0.991731  0.572531  0.226080  0.785044  0.312688
# 1  0.672409  0.362699  0.977462  0.684656  0.051541
# 2  0.781430  0.776446  0.975886  0.006406  0.604181
# 3  0.365634  0.717888  0.666372  0.766964  0.724479
# 4  0.559252  0.744348  0.626295  0.547583  0.383909

# %% [markdown]
# ## Section 3: Data Selection, Filtering, and Grouping
# These operations help extract useful information from data and are commonly used during feature selection and exploratory data analysis.

# %%
newDfView.head()
# Out:
#           0         1         2         3         4
# 0  0.991731  0.572531  0.226080  0.785044  0.312688
# 1  0.672409  0.362699  0.977462  0.684656  0.051541
# 2  0.781430  0.776446  0.975886  0.006406  0.604181
# 3  0.365634  0.717888  0.666372  0.766964  0.724479
# 4  0.559252  0.744348  0.626295  0.547583  0.383909

# %%
newDfCopy=newDf.copy()

# %%
newDfCopy[0][0]=656
# Out:
# C:\Users\engin\AppData\Local\Temp\ipykernel_23084\2532441962.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   newDfCopy[0][0]=656

# %%
newDf.head()
# Out:
#           0         1         2         3         4
# 0  0.991731  0.572531  0.226080  0.785044  0.312688
# 1  0.672409  0.362699  0.977462  0.684656  0.051541
# 2  0.781430  0.776446  0.975886  0.006406  0.604181
# 3  0.365634  0.717888  0.666372  0.766964  0.724479
# 4  0.559252  0.744348  0.626295  0.547583  0.383909

# %%
newDfCopy.head()
# Out:
#           0         1         2         3         4
# 0  0.991731  0.572531  0.226080  0.785044  0.312688
# 1  0.672409  0.362699  0.977462  0.684656  0.051541
# 2  0.781430  0.776446  0.975886  0.006406  0.604181
# 3  0.365634  0.717888  0.666372  0.766964  0.724479
# 4  0.559252  0.744348  0.626295  0.547583  0.383909

# %%
import pandas as pd

# Create a sample DataFrame
data = {
    "Student": ["Ali", "Sara", "Bilal", "Hina"],
    "Marks": [85, 92, 76, 89],
    "Age": [20, 21, 19, 22]
}

df = pd.DataFrame(data)
print("Original DataFrame:\n", df)
# Out:
# Original DataFrame:
#    Student  Marks  Age
# 0     Ali     85   20
# 1    Sara     92   21
# 2   Bilal     76   19
# 3    Hina     89   22

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Student  4 non-null      str
#  1   Marks    4 non-null      int64
#  2   Age      4 non-null      int64
# dtypes: int64(2), str(1)
# memory usage: 228.0 bytes
# None

# %%
print("\nDescribe:\n", df.describe())
# Out:
# Describe:
#             Marks        Age
# count   4.000000   4.000000
# mean   85.500000  20.500000
# std     6.952218   1.290994
# min    76.000000  19.000000
# 25%    82.750000  19.750000
# 50%    87.000000  20.500000
# 75%    89.750000  21.250000
# max    92.000000  22.000000

# %%
# -----------------------------
# 2. SORTING
# -----------------------------
print("\nSorting by Marks (descending):\n", df.sort_values("Marks", ascending=False))
print("\nSorting by Age (ascending):\n", df.sort_values("Age"))
# Out:
# Sorting by Marks (descending):
#    Student  Marks  Age
# 1    Sara     92   21
# 3    Hina     89   22
# 0     Ali     85   20
# 2   Bilal     76   19
#
# Sorting by Age (ascending):
#    Student  Marks  Age
# 2   Bilal     76   19
# 0     Ali     85   20
# 1    Sara     92   21
# 3    Hina     89   22

# %%
# -----------------------------
# 3. TRANSPOSE
# -----------------------------
print("\nTransposed DataFrame:\n", df.T)
# Out:
# Transposed DataFrame:
#             0     1      2     3
# Student  Ali  Sara  Bilal  Hina
# Marks     85    92     76    89
# Age       20    21     19    22

# %% [markdown]
# ## Slicing through loc function

# %%
import pandas as pd

# Sample DataFrame
data = {
    "Name": ["Ali", "Sara", "Bilal", "Hina"],
    "Marks": [85, 92, 76, 89],
    "Age": [20, 21, 19, 22]
}

df = pd.DataFrame(data)
print("Original DataFrame:\n", df)
# Out:
# Original DataFrame:
#      Name  Marks  Age
# 0    Ali     85   20
# 1   Sara     92   21
# 2  Bilal     76   19
# 3   Hina     89   22

# %%
# 1. Select row with label 2
print(df.loc[2])
# Out:
# Name     Bilal
# Marks       76
# Age         19
# Name: 2, dtype: object

# %%
# 2. Select specific rows and columns by NAME
print(df.loc[1:3, ["Name", "Marks"]])
# Out:
#     Name  Marks
# 1   Sara     92
# 2  Bilal     76
# 3   Hina     89

# %%
# 3. Applying Filter: Conditional selection: students with Marks > 85
print(df.loc[df["Marks"] > 85])
# Out:
#    Name  Marks  Age
# 1  Sara     92   21
# 3  Hina     89   22

# %% [markdown]
# ##  Slicing through iloc

# %%
df
# Out:
#     Name  Marks  Age
# 0    Ali     85   20
# 1   Sara     92   21
# 2  Bilal     76   19
# 3   Hina     89   22

# %%
# 1. Select row at index 0
print(df.iloc[0])
# Out:
# Name     Ali
# Marks     85
# Age       20
# Name: 0, dtype: object

# %%
# 2. Select 2 rows and 2 columns by position
print(df.iloc[0:2, 0:2])
# Out:
#    Name  Marks
# 0   Ali     85
# 1  Sara     92

# %%
# 3. Select last row using negative index
print(df.iloc[-1])
# Out:
# Name     Hina
# Marks      89
# Age        22
# Name: 3, dtype: object

# %% [markdown]
# # Dropping the Row

# %%
df
# Out:
#     Name  Marks  Age
# 0    Ali     85   20
# 1   Sara     92   21
# 2  Bilal     76   19
# 3   Hina     89   22

# %%
df.drop(0).head()
# Out:
#     Name  Marks  Age
# 1   Sara     92   21
# 2  Bilal     76   19
# 3   Hina     89   22

# %% [markdown]
# # Dropping the col

# %%
df.drop(['Age'], axis=1).head()
# Out:
#     Name  Marks
# 0    Ali     85
# 1   Sara     92
# 2  Bilal     76
# 3   Hina     89

# %%
df.head()
# Out:
#     Name  Marks  Age
# 0    Ali     85   20
# 1   Sara     92   21
# 2  Bilal     76   19
# 3   Hina     89   22

# %%
df.drop(['Age'], axis=1, inplace=True)

# %%
df.head()
# Out:
#     Name  Marks
# 0    Ali     85
# 1   Sara     92
# 2  Bilal     76
# 3   Hina     89

# %%
df.reset_index().head()
# Out:
#    index   Name  Marks
# 0      0    Ali     85
# 1      1   Sara     92
# 2      2  Bilal     76
# 3      3   Hina     89

# %%
df.reset_index(drop=True).head()
# Out:
#     Name  Marks
# 0    Ali     85
# 1   Sara     92
# 2  Bilal     76
# 3   Hina     89

# %%
df.head()
# Out:
#     Name  Marks
# 0    Ali     85
# 1   Sara     92
# 2  Bilal     76
# 3   Hina     89

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#     Name  Marks
# 0    Ali     85
# 1   Sara     92
# 2  Bilal     76
# 3   Hina     89

# %% [markdown]
# # Groupby
# The groupby method allows you to group rows of data together and call aggregate functions
#
# ​
# ​

# %%
data = {'Company':['GOOG','GOOG','MSFT','MSFT','FB','FB'],
       'Person':['Sam','Charlie','Amy','Vanessa','Carl','Sarah'],
       'Sales':[200,120,340,124,243,350]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   Company   Person  Sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %% [markdown]
# ### Now you can use the .groupby() method to group rows together based off of a column name.
# For instance let's group based off of Company. This will create a DataFrameGroupBy object:

# %%
df.groupby('Company')

# %% [markdown]
# ##### You can save this object as a new variable:

# %%
by_comp = df.groupby("Company")
type(by_comp)
# Out:
# pandas.api.typing.DataFrameGroupBy

# %% [markdown]
# #### And then call aggregate methods of the object:

# %%
by_comp.std(numeric_only=True)
# Out:
#               Sales
# Company
# FB        75.660426
# GOOG      56.568542
# MSFT     152.735065

# %%
df.groupby('Company').std(numeric_only=True)
# Out:
#               Sales
# Company
# FB        75.660426
# GOOG      56.568542
# MSFT     152.735065

# %%
by_comp.std(numeric_only=True)
# Out:
#               Sales
# Company
# FB        75.660426
# GOOG      56.568542
# MSFT     152.735065

# %%
by_comp.min()
# Out:
#           Person  Sales
# Company
# FB          Carl    243
# GOOG     Charlie    120
# MSFT         Amy    124

# %%
by_comp.max()
# Out:
#           Person  Sales
# Company
# FB         Sarah    350
# GOOG         Sam    200
# MSFT     Vanessa    340

# %%
by_comp.count()
# Out:
#          Person  Sales
# Company
# FB            2      2
# GOOG          2      2
# MSFT          2      2

# %%
by_comp.describe()
# Out:
#         Sales
#         count   mean         std    min     25%    50%     75%    max
# Company
# FB        2.0  296.5   75.660426  243.0  269.75  296.5  323.25  350.0
# GOOG      2.0  160.0   56.568542  120.0  140.00  160.0  180.00  200.0
# MSFT      2.0  232.0  152.735065  124.0  178.00  232.0  286.00  340.0

# %% [markdown]
# ## Final Conclusion
# In this lab, Pandas was used for tabular data handling. These skills are important for dataset collection, inspection, cleaning, and preparation before model training.
