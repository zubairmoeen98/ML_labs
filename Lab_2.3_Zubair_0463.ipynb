# %% [markdown]
# # Lab 2.3: Introduction to Matplotlib
#
# **Name:** Zubair Moeen
# **Reg Number:** 22jzele0463
# **Lab:** Machine Learning Lab
# **Lab Supervisor:** Engr.Irshad Ullah
# **University:** UET Peshawar - Campus Nowshera
#
# ## Lab Overview
# This notebook introduces Matplotlib for data visualization. The code demonstrates line plots, titles, labels, grids, markers, colors, bar charts, scatter plots, histograms, and subplots.
#
# ## Learning Objectives
# - Import Matplotlib using the standard pyplot alias plt.
# - Create basic line plots and customize them with titles, labels, legends, grids, markers, and colors.
# - Visualize data using bar plots, scatter plots, histograms, and multiple subplots.
# - Understand why visualization is important for exploratory data analysis in machine learning.

# %% [markdown]
# ## Section 1: Matplotlib Setup and Basic Line Plot
# This section starts with importing Matplotlib and drawing simple plots. Visualization helps understand the behavior and pattern of data.

# %% [markdown]
# # Lab 3.3 - Introduction to Matplotlib
#
# Matplotlib is the most popular Python library for creating static, animated, and interactive visualizations.
# It is very powerful and highly customizable — almost every kind of chart used in data science, reports, research, and teaching can be created with Matplotlib.
#
# ### Installation
# ```bash
# pip install matplotlib

# %% [markdown]
# # Import Matplotlib
# We usually import it with the alias plt (this is the standard convention):

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Basic Plot – Line Plot

# %%
# Simple line plot
x = [1, 2, 3, 4, 5]
y = [10, 12, 8, 15, 11]

plt.plot(x, y)
plt.show()

# %% [markdown]
# ## 2. Adding Titles, Labels and Grid

# %%
x = [1, 2, 3, 4, 5]
y = [10, 12, 8, 15, 11]

plt.plot(x, y)

plt.title("Student Marks Over Days")
plt.xlabel("Days")
plt.ylabel("Marks")

plt.grid(True)

plt.show()

# %% [markdown]
# ## 3. Change Style: Color, Marker, Line Style

# %%
x = [1, 2, 3, 4, 5]
y = [10, 12, 8, 15, 11]

plt.plot(x, y, 
         color='red', 
         marker='o', 
         linestyle='--', 
         linewidth=2, 
         markersize=8)

plt.title("Styled Line Plot")
plt.xlabel("Days")
plt.ylabel("Marks")
plt.grid(True)

plt.show()

# %% [markdown]
# ## Section 2: Plot Customization
# The next cells add labels, titles, grids, markers, and colors. These details make graphs easier to read and present professionally.

# %% [markdown]
# Common marker styles:
# - 'o' → circle
# - 's' → square
# - '^' → triangle
# - 'D' → diamond
# - '*' → star
#
# Common line styles:
# - '-'  solid
# - '--' dashed
# - ':'  dotted
# - '-.' dash-dot

# %% [markdown]
# ## 4. Multiple Lines in One Plot

# %%
days = [1, 2, 3, 4, 5]

math = [85, 88, 82, 90, 87]
science = [78, 85, 80, 92, 88]
english = [90, 87, 91, 85, 89]

plt.plot(days, math, label='Math', marker='o')
plt.plot(days, science, label='Science', marker='s')
plt.plot(days, english, label='English', marker='^')

plt.title("Student Marks Comparison")
plt.xlabel("Days")
plt.ylabel("Marks")
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# ## 5. Bar Plot

# %%
subjects = ['Math', 'Science', 'English', 'Urdu', 'Physics']
marks = [88, 85, 90, 78, 92]

plt.bar(subjects, marks, color=['#4CAF50', '#2196F3', '#FF9800', '#F44336', '#9C27B0'])

plt.title("Class Average Marks")
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.ylim(0, 100)

plt.show()

# %% [markdown]
# ## 6. Horizontal Bar Plot

# %%
plt.barh(subjects, marks, color='skyblue')

plt.title("Horizontal Bar - Class Performance")
plt.xlabel("Marks")
plt.ylabel("Subjects")

plt.show()

# %% [markdown]
# ## 7. Scatter Plot

# %%
hours_studied = [2, 3, 5, 6, 7, 8, 9, 1, 4, 10]
exam_marks = [45, 55, 70, 78, 82, 85, 88, 40, 65, 92]

plt.scatter(hours_studied, exam_marks, 
            color='purple', 
            marker='o', 
            s=10,          # size
            alpha=0.9)      # transparency

plt.title("Study Hours vs Exam Marks")
plt.xlabel("Hours Studied")
plt.ylabel("Marks Obtained")
plt.grid(True)

plt.show()

# %% [markdown]
# ## 8. Histogram

# %%
marks = [45, 55, 60, 62, 65, 68, 70, 72, 75, 78, 80, 82, 85, 88, 90, 92, 95, 98, 100]

plt.hist(marks, bins=10, color='teal', edgecolor='black')

plt.title("Marks Distribution")
plt.xlabel("Marks")
plt.ylabel("Number of Students")

plt.show()

# %% [markdown]
# ## Section 3: Different Plot Types
# The remaining examples show different visualization types such as bar charts, scatter plots, histograms, and subplots used during ML data exploration.

# %% [markdown]
# ## 9. Pie Chart

# %%
subjects = ['Math', 'Science', 'English', 'Urdu', 'Physics']
marks = [88, 85, 90, 78, 92]

plt.pie(marks, labels=subjects, autopct='%1.1f%%', startangle=90, colors=['#ff9999','#66b3ff','#99ff99','#ffcc99','#c2c2f0'])

plt.title("Subject-wise Marks Percentage")
plt.axis('equal')  # equal aspect ratio → perfect circle

plt.show()

# %% [markdown]
# ## 10. Subplots (Multiple Plots in One Figure)

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

# Plot 1
axes[0, 0].plot([1,2,3,4], [10,20,25,30], 'b-o')
axes[0, 0].set_title("Line Plot")

# Plot 2
axes[0, 1].bar(['A','B','C'], [5,7,3], color='orange')
axes[0, 1].set_title("Bar Plot")

# Plot 3
axes[1, 0].scatter([1,2,3,4,5], [2,5,3,8,1], color='green')
axes[1, 0].set_title("Scatter Plot")

# Plot 4
axes[1, 1].hist([1,2,2,3,3,3,4,5,5], bins=5, color='purple')
axes[1, 1].set_title("Histogram")

plt.tight_layout()  # avoids overlapping
plt.show()

# %% [markdown]
# ## Mini Exercises for Students
#
# 1. Create a line plot showing temperature for 7 days (make up reasonable values).
# 2. Make a bar chart of 5 favorite fruits and how many students like each.
# 3. Create a scatter plot of student height vs weight (at least 8 students).
# 4. Make a pie chart showing time spent on different activities in a day (study, sleep, play, etc.).
# 5. Create a histogram of marks of 20 students (you can make up the data).
# 6. Combine two plots in one figure using subplots: line plot + bar plot.
#
# Try to add titles, labels, grid, legend, colors, and markers wherever possible!

# %%
import matplotlib.pyplot as plt

# %%
# 1. Create mock data for the two plots
days = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
temperatures = [22, 24, 21, 25, 27, 26, 23]  # Data for the line plot

fruits = ['Apples', 'Bananas', 'Oranges', 'Grapes', 'Berries']
votes = [12, 18, 8, 15, 10]                  # Data for the bar chart

# %%
# 2. Setup a figure with a 1-row, 2-column grid layout
# figsize setting controls the overall width and height of the window
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# LEFT PLOT: Line Plot (Index 0)
axes[0].plot(days, temperatures, color='blue', marker='o', linestyle='-', linewidth=2)
axes[0].set_title('Weekly Temperature (Line Plot)')
axes[0].set_xlabel('Days of the Week')
axes[0].set_ylabel('Temperature (°C)')
axes[0].grid(True, linestyle='--', alpha=0.6)  # Optional helper grid lines

# RIGHT PLOT: Bar Chart (Index 1)
axes[1].bar(fruits, votes, color='orange', edgecolor='black')
axes[1].set_title('Favorite Fruits (Bar Plot)')
axes[1].set_xlabel('Fruit Names')
axes[1].set_ylabel('Number of Students')
# Out:
# Text(0, 0.5, 'Number of Students')

# %%
# 3. Clean up the spacing so titles and axis labels do not overlap
plt.tight_layout()

# %%
# 4. Display the finalized combined figure
plt.show()

# %% [markdown]
# ## Final Conclusion
# In this lab, Matplotlib was used to visualize data in different formats. These plotting skills are useful for understanding datasets, model behavior, and final results in machine learning projects.
